# %%
import numpy as np
import re

# %%
def redpr(str):
    print('\x1b[31m' + str + '\x1b[0m')
    
def greenpr(str):
    print('\x1b[32m' + str + '\x1b[0m')
    
def colorpr2(str0, str1, col1, str2, col2):
    print(str0 + '\x1b[' + col1 + 'm' + str1.rjust(8) + '\x1b[0m', '\x1b[' + col2 + 'm' + str2.rjust(16) + '\x1b[0m')

# %%
week = 25
lastweek = week - 1
wk = str(week)
lwk = str(lastweek)

with open('Week' + lwk + '/Games_w' + wk + '.txt') as f:
    #passer = f.readlines()
    Games = list(f)

with open('Week' + lwk + '/Goals_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Goals = list(f)
    
with open('Week' + lwk + '/FormL6_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    FormL6 = list(f)
    
#with open('Week' + lwk + '/Corners_w' + lwk + '.txt') as f:
    #passer = f.readlines()
#    Corners = list(f)
    
with open('Week' + lwk + '/Passes_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Passes = list(f)
    
with open('Week' + lwk + '/Shots_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Shots = list(f)
    
#with open('Week' + lwk + '/BigChances_w' + lwk + '.txt') as f:
    #passer = f.readlines()
#    BigChances = list(f)
    
#with open('Woche' + lwk + '/Eckbälle_w' + lwk + '.txt') as f:
    #passer = f.readlines()
#    Eckbälle = list(f)

# %%
team_list = []
data_dict = {}

for i in range(24):
    
    # Passes:
    j1 = Passes[i].index('\t')
    j2 = Passes[i].index('\t', j1 + 1)
    team = Passes[i].lstrip().rstrip()[j1 + 1:j2 - 1]
    team_list.append(team)
    
    rnk = i + 1
    
    data_dict[team] = {}
    data_dict[team]['Passes'] = rnk
    
team_list = sorted(team_list)

for i in range(24):
    
    # Passes:
    #j1 = Passes[2*i + 1].index('\t')
    #team = Passes[2*i + 1].lstrip().rstrip()[:j1]
    #rnk = i + 1
    #data_dict[team]['Passes'] = rnk
    
    # Shots:
    j1 = Shots[i].index('\t')
    j2 = Shots[i].index('\t', j1 + 1)
    team = Shots[i].lstrip().rstrip()[j1 + 1:j2 - 1]
    rnk = i + 1
    data_dict[team]['Shots'] = rnk
    
    # BigChances:
    #j1 = BigChances[2*i + 1].index('\t')
    #team = BigChances[2*i + 1].lstrip().rstrip()[:j1]
    #rnk = i + 1
    #data_dict[team]['BigChances'] = rnk
    
data_dict
# Out:
# {'Swansea': {'Passes': 1, 'Shots': 14},
#  'Aston Villa': {'Passes': 2, 'Shots': 6},
#  'Brentford': {'Passes': 3, 'Shots': 3},
#  'Leeds': {'Passes': 4, 'Shots': 1},
#  'Norwich': {'Passes': 5, 'Shots': 2},
#  'West Bromwich Albion': {'Passes': 6, 'Shots': 4},
#  'Derby': {'Passes': 7, 'Shots': 5},
#  'Stoke': {'Passes': 8, 'Shots': 18},
#  'Sheffield United': {'Passes': 9, 'Shots': 9},
#  'Nottingham Forest': {'Passes': 10, 'Shots': 17},
#  'Sheffield Wednesday': {'Passes': 11, 'Shots': 20},
#  'Reading': {'Passes': 12, 'Shots': 21},
#  'Middlesbrough': {'Passes': 13, 'Shots': 8},
#  'Bristol City': {'Passes': 14, 'Shots': 11},
#  'Preston': {'Passes': 15, 'Shots': 12},
#  'Wigan': {'Passes': 16, 'Shots': 16},
#  'Blackburn': {'Passes': 17, 'Shots': 19},
#  'Queens Park Rangers': {'Passes': 18, 'Shots': 10},
#  'Hull': {'Passes': 19, 'Shots': 22},
#  'Bolton': {'Passes': 20, 'Shots': 23},
#  'Ipswich': {'Passes': 21, 'Shots': 24},
#  'Millwall': {'Passes': 22, 'Shots': 13},
#  'Rotherham': {'Passes': 23, 'Shots': 7},
#  'Birmingham': {'Passes': 24, 'Shots': 15}}

# %%
for i in range(2, 26):
    
    Goals[i] = re.sub('Birmingham City', 'Birmingham', Goals[i])
    Goals[i] = re.sub('Derby County', 'Derby', Goals[i])
    Goals[i] = re.sub('Hull City', 'Hull', Goals[i])
    Goals[i] = re.sub('Ipswich Town', 'Ipswich', Goals[i])
    Goals[i] = re.sub('Leeds Utd', 'Leeds', Goals[i])
    Goals[i] = re.sub('Norwich City', 'Norwich', Goals[i])
    Goals[i] = re.sub('Nottm Forest', 'Nottingham Forest', Goals[i])
    Goals[i] = re.sub('QP Rangers', 'Queens Park Rangers', Goals[i])
    Goals[i] = re.sub('Sheffield Utd', 'Sheffield United', Goals[i])
    Goals[i] = re.sub('Sheffield Wed', 'Sheffield Wednesday', Goals[i])
    Goals[i] = re.sub('Stoke City', 'Stoke', Goals[i])
    Goals[i] = re.sub('Swansea City', 'Swansea', Goals[i])
    Goals[i] = re.sub('West Bromwich', 'West Bromwich Albion', Goals[i])
    Goals[i] = re.sub('Wigan Athletic', 'Wigan', Goals[i])
    
for i in range(2, 26):
    
    j1 = Goals[i].index('\t')
    team = Goals[i][:j1].lstrip().rstrip()
    print(team)
    j2 = Goals[i].index('\t', j1 + 1) 
    scored_home = float(Goals[i].lstrip()[j1:j2].rstrip())
    j3 = Goals[i].index('\t', j2 + 1) 
    conceded_home = float(Goals[i].lstrip()[j2:j3].rstrip())
    j4 = Goals[i].index('\t', j3 + 1)
    j5 = Goals[i].index('\t', j4 + 1)
    j6 = Goals[i].index('\t', j5 + 1)
    scored_away = float(Goals[i].lstrip()[j5:j6].rstrip())
    j7 = Goals[i].index('\t', j6 + 1)
    conceded_away = float(Goals[i].lstrip()[j6:j7].rstrip())
    j8 = Goals[i].index('\t', j7 + 1)
    j9 = Goals[i].index('\t', j8 + 1)
    j10 = Goals[i].index('\t', j9 + 1)
    scored_tot = float(Goals[i].lstrip()[j9:j10].rstrip())
    j11 = Goals[i].index('\t', j10 + 1)
    conceded_tot = float(Goals[i].lstrip()[j10:j11].rstrip())
    
    margin_home = scored_home - conceded_home
    margin_away = scored_away - conceded_away
    margin_tot = scored_tot - conceded_tot
    
    data_dict[team]['margin home'] = margin_home
    data_dict[team]['margin away'] = margin_away
    data_dict[team]['margin tot'] = margin_tot
# Out:
# Aston Villa
# Birmingham
# Blackburn
# Bolton
# Brentford
# Bristol City
# Derby
# Hull
# Ipswich
# Leeds
# Middlesbrough
# Millwall
# Norwich
# Nottingham Forest
# Preston
# Queens Park Rangers
# Reading
# Rotherham
# Sheffield United
# Sheffield Wednesday
# Stoke
# Swansea
# West Bromwich Albion
# Wigan

# %%
for i in range(24):
    
    FormL6[i] = re.sub('Birmingham City', 'Birmingham', FormL6[i])
    FormL6[i] = re.sub('Derby County', 'Derby', FormL6[i])
    FormL6[i] = re.sub('Hull City', 'Hull', FormL6[i])
    FormL6[i] = re.sub('Ipswich Town', 'Ipswich', FormL6[i])
    FormL6[i] = re.sub('Leeds Utd', 'Leeds', FormL6[i])
    FormL6[i] = re.sub('Norwich City', 'Norwich', FormL6[i])
    FormL6[i] = re.sub('Nottm Forest', 'Nottingham Forest', FormL6[i])
    FormL6[i] = re.sub('QP Rangers', 'Queens Park Rangers', FormL6[i])
    FormL6[i] = re.sub('Sheffield Utd', 'Sheffield United', FormL6[i])
    FormL6[i] = re.sub('Sheffield Wed', 'Sheffield Wednesday', FormL6[i])
    FormL6[i] = re.sub('Stoke City', 'Stoke', FormL6[i])
    FormL6[i] = re.sub('Swansea City', 'Swansea', FormL6[i])
    FormL6[i] = re.sub('West Bromwich', 'West Bromwich Albion', FormL6[i])
    FormL6[i] = re.sub('Wigan Athletic', 'Wigan', FormL6[i])
    
for i in range(24):
    
    j1 = FormL6[i].index('\t')
    j2 = FormL6[i].index('\t', j1 + 1) 
    j3 = FormL6[i].index('\t', j2 + 1) 
    j4 = FormL6[i].index('\t', j3 + 1) 
    j5 = FormL6[i].index('\t', j4 + 1) 
    j6 = FormL6[i].index('\t', j5 + 1) 
    j7 = FormL6[i].index('\t', j6 + 1) 
    j8 = FormL6[i].index('\t', j7 + 1) 
    j9 = FormL6[i].index('\t', j8 + 1) 
    team = FormL6[i][j1:j2].lstrip().rstrip()
    #print(team)
    diff = float(FormL6[i][j8:j9].lstrip().rstrip())
    #print('diff:', diff/6.)
    data_dict[team]['margin form'] = diff/6.

# %%
margin_ar = []
marginHome_ar = []
marginAway_ar = []
marginForm_ar = []
stats_ar = []
means = np.zeros((24, 2))

i = 0
for team in team_list:
    margin_ar.append([data_dict[team]['margin tot'], team]) 
    marginHome_ar.append([data_dict[team]['margin home'], team])
    marginAway_ar.append([data_dict[team]['margin away'], team])
    marginForm_ar.append([data_dict[team]['margin form'], team])
    #rnk_1 = data_dict[team]['Corners']
    rnk_2 = data_dict[team]['Passes']
    rnk_3 = data_dict[team]['Shots']
    #rnk_4 = data_dict[team]['BigChances']
    means[i, 0] = data_dict[team]['margin home']
    means[i, 1] = data_dict[team]['margin away']
    i +=1
    
    # divided by 6.0 to get the margin:
    stats_val = np.mean([rnk_2, rnk_3])/7.0
    stats_ar.append([stats_val, team, rnk_2, rnk_3])
    data_dict[team]['margin stats'] = stats_val
    
margin_rankings = sorted(margin_ar, reverse=True)
marginHome_rankings = sorted(marginHome_ar, reverse=True)
marginAway_rankings = sorted(marginAway_ar, reverse=True)
marginForm_rankings = sorted(marginForm_ar, reverse=True)
stats_rankings = sorted(stats_ar, reverse=False)

meanHome = np.mean(means[:, 0])
meanAway = np.mean(means[:, 1])
print('meanHome: ', meanHome)
print('meanAway: ', meanAway)
print()

print('margin:')
print()
for i in range(24):
    print('{:2d}'.format(i + 1), margin_rankings[i][1].rjust(30), '{0:+5.1f}'.format(margin_rankings[i][0] ))

print()
print('marginHome:')
print()
for i in range(24):
    print('{:2d}'.format(i + 1), marginHome_rankings[i][1].rjust(30), '{0:+5.1f}'.format(marginHome_rankings[i][0] ))

print()
print('marginAway:')
print()
for i in range(24):
    print('{:2d}'.format(i + 1), marginAway_rankings[i][1].rjust(30), '{0:+5.1f}'.format(marginAway_rankings[i][0] ))

print()
print('marginForm:')
print()
for i in range(24):
    print('{:2d}'.format(i + 1), marginForm_rankings[i][1].rjust(30), '{0:+5.1f}'.format(marginForm_rankings[i][0] ))
    
print()
print('marginStats:')
print()
for i in range(24):
    print('{:2d}'.format(i + 1), stats_rankings[i][1].rjust(30), '{0:5.1f}'.format(stats_rankings[i][0]), '  {}'.format(stats_rankings[i][2:] ))
# Out:
# meanHome:  0.278333333333
# meanAway:  -0.278333333333
#
# margin:
#
#  1           West Bromwich Albion  +0.9
#  2                          Leeds  +0.8
#  3                        Norwich  +0.6
#  4               Sheffield United  +0.5
#  5                     Birmingham  +0.4
#  6              Nottingham Forest  +0.4
#  7                    Aston Villa  +0.4
#  8                  Middlesbrough  +0.3
#  9                          Derby  +0.2
# 10                        Swansea  +0.0
# 11                          Stoke  +0.0
# 12                   Bristol City  +0.0
# 13                      Brentford  +0.0
# 14            Queens Park Rangers  -0.0
# 15                        Preston  -0.2
# 16                           Hull  -0.2
# 17                      Blackburn  -0.2
# 18                        Reading  -0.4
# 19            Sheffield Wednesday  -0.4
# 20                       Millwall  -0.4
# 21                          Wigan  -0.5
# 22                         Bolton  -0.6
# 23                      Rotherham  -0.7
# 24                        Ipswich  -0.9
#
# marginHome:
#
#  1           West Bromwich Albion  +1.2
#  2                          Leeds  +1.1
#  3                     Birmingham  +0.8
#  4                      Brentford  +0.7
#  5               Sheffield United  +0.6
#  6                        Preston  +0.6
#  7            Queens Park Rangers  +0.5
#  8                    Aston Villa  +0.5
#  9                        Norwich  +0.4
# 10                          Derby  +0.3
# 11                          Stoke  +0.3
# 12              Nottingham Forest  +0.3
# 13                       Millwall  +0.2
# 14                  Middlesbrough  +0.2
# 15                          Wigan  +0.2
# 16                        Swansea  +0.2
# 17                      Blackburn  +0.2
# 18                   Bristol City  +0.0
# 19                      Rotherham  -0.1
# 20                           Hull  -0.1
# 21            Sheffield Wednesday  -0.2
# 22                        Reading  -0.2
# 23                        Ipswich  -0.4
# 24                         Bolton  -0.7
#
# marginAway:
#
#  1                        Norwich  +0.8
#  2                          Leeds  +0.6
#  3           West Bromwich Albion  +0.5
#  4              Nottingham Forest  +0.5
#  5                  Middlesbrough  +0.4
#  6               Sheffield United  +0.3
#  7                    Aston Villa  +0.2
#  8                          Derby  +0.1
#  9                   Bristol City  +0.1
# 10                     Birmingham  +0.1
# 11                        Swansea  -0.1
# 12                          Stoke  -0.2
# 13                           Hull  -0.3
# 14            Queens Park Rangers  -0.6
# 15                         Bolton  -0.6
# 16                        Reading  -0.7
# 17            Sheffield Wednesday  -0.7
# 18                      Brentford  -0.7
# 19                      Blackburn  -0.7
# 20                        Preston  -0.9
# 21                       Millwall  -1.1
# 22                          Wigan  -1.2
# 23                      Rotherham  -1.2
# 24                        Ipswich  -1.4
#
# marginForm:
#
#  1                     Birmingham  +1.5
#  2           West Bromwich Albion  +1.3
#  3                          Leeds  +1.0
#  4                           Hull  +0.8
#  5                        Norwich  +0.7
#  6               Sheffield United  +0.5
#  7            Queens Park Rangers  +0.5
#  8                    Aston Villa  +0.5
#  9                          Stoke  +0.3
# 10                   Bristol City  +0.3
# 11            Sheffield Wednesday  +0.0
# 12              Nottingham Forest  +0.0
# 13                          Derby  -0.2
# 14                        Swansea  -0.3
# 15                      Blackburn  -0.3
# 16                        Preston  -0.5
# 17                       Millwall  -0.5
# 18                      Brentford  -0.5
# 19                         Bolton  -0.5
# 20                  Middlesbrough  -0.7
# 21                          Wigan  -0.8
# 22                        Reading  -0.8
# 23                      Rotherham  -1.2
# 24                        Ipswich  -1.2
#
# marginStats:
#
#  1                          Leeds   0.4   [4, 1]
#  2                      Brentford   0.4   [3, 3]
#  3                        Norwich   0.5   [5, 2]
#  4                    Aston Villa   0.6   [2, 6]
#  5           West Bromwich Albion   0.7   [6, 4]
#  6                          Derby   0.9   [7, 5]
#  7                        Swansea   1.1   [1, 14]
#  8               Sheffield United   1.3   [9, 9]
#  9                  Middlesbrough   1.5   [13, 8]
# 10                   Bristol City   1.8   [14, 11]
# 11                          Stoke   1.9   [8, 18]
# 12              Nottingham Forest   1.9   [10, 17]
# 13                        Preston   1.9   [15, 12]
# 14            Queens Park Rangers   2.0   [18, 10]
# 15                      Rotherham   2.1   [23, 7]
# 16            Sheffield Wednesday   2.2   [11, 20]
# 17                          Wigan   2.3   [16, 16]
# 18                        Reading   2.4   [12, 21]
# 19                       Millwall   2.5   [22, 13]
# 20                      Blackburn   2.6   [17, 19]
# 21                     Birmingham   2.8   [24, 15]
# 22                           Hull   2.9   [19, 22]
# 23                         Bolton   3.1   [20, 23]
# 24                        Ipswich   3.2   [21, 24]

# %%
margin_rankings[-1][0]
# Out:
# -0.9199999999999999

# %%
Games
# Out:
# ['Sat. 29 Dec. 16:00 \t Birmingham City - Brentford \t\t\n',
#  'Sat. 29 Dec. 16:00 \t Bolton - Stoke City \t\t\n',
#  'Sat. 29 Dec. 16:00 \t Bristol City - Rotherham \t\t\n',
#  'Sat. 29 Dec. 16:00 \t Leeds Utd - Hull City \t\t\n',
#  'Sat. 29 Dec. 16:00 \t Middlesbrough - Ipswich Town \t\t\n',
#  'Sat. 29 Dec. 16:00 \t Millwall - Nottm Forest \t\t\n',
#  'Sat. 29 Dec. 16:00 \t Norwich City - Derby County \t\t\n',
#  'Sat. 29 Dec. 16:00 \t Preston - Aston Villa \t\t\n',
#  'Sat. 29 Dec. 16:00 \t QP Rangers - Reading \t\t\n',
#  'Sat. 29 Dec. 16:00 \t Sheffield Utd - Blackburn \t\t\n',
#  'Sat. 29 Dec. 16:00 \t Swansea City - Wigan Athletic \t\t\n',
#  'Sat. 29 Dec. 16:00 \t West Bromwich - Sheffield Wed \t']

# %%
coeff = meanAway - meanHome
print('coeff = ', coeff)
print()

for i in range(len(Games)):
    
    Games[i] = re.sub('Birmingham City', 'Birmingham', Games[i])
    Games[i] = re.sub('Derby County', 'Derby', Games[i])
    Games[i] = re.sub('Hull City', 'Hull', Games[i])
    Games[i] = re.sub('Ipswich Town', 'Ipswich', Games[i])
    Games[i] = re.sub('Leeds Utd', 'Leeds', Games[i])
    Games[i] = re.sub('Norwich City', 'Norwich', Games[i])
    Games[i] = re.sub('Nottm Forest', 'Nottingham Forest', Games[i])
    Games[i] = re.sub('QP Rangers', 'Queens Park Rangers', Games[i])
    Games[i] = re.sub('Sheffield Utd', 'Sheffield United', Games[i])
    Games[i] = re.sub('Sheffield Wed', 'Sheffield Wednesday', Games[i])
    Games[i] = re.sub('Stoke City', 'Stoke', Games[i])
    Games[i] = re.sub('Swansea City', 'Swansea', Games[i])
    Games[i] = re.sub('West Bromwich', 'West Bromwich Albion', Games[i])
    Games[i] = re.sub('Wigan Athletic', 'Wigan', Games[i])

f = open('Week' + lwk + '/Lines_w' + wk + '.txt', 'w')
for i in range(len(Games)):
    
    j1 = Games[i].index('\t')
    j2 = Games[i].index('-', j1 + 1)
    j3 = Games[i].index('\t', j2 + 1)

    teamHome = Games[i][j1:j2].rstrip().lstrip()
    teamAway = Games[i][j2 + 1:j3].rstrip().lstrip()

    spread1 = coeff - data_dict[teamHome]['margin tot'] + data_dict[teamAway]['margin tot']
    spread2 = - data_dict[teamHome]['margin home'] + data_dict[teamAway]['margin away']
    spread12 = (spread1 + spread2)/2.
    
    #rnk_1 = data_dict[teamHome]['Corners']
    #col_1 = '30'
    #if rnk_1 <= 6:
    #    col_1 = '32'
    #elif rnk_1 >= 15:
    #    col_1 = '31'
    #str_1 = str(rnk_1).rjust(3)

    #rnk_2 = data_dict[teamAway]['Corners']
    #col_2 = '30'
    #if rnk_2 <= 6:
    #    col_2 = '32'
    #elif rnk_2 >= 15:
    #    col_2 = '31'
    #str_2 = str(rnk_2).rjust(3)

    rnk_3 = data_dict[teamHome]['Passes']
    col_3 = '30'
    if rnk_3 <= 6:
        col_3 = '32'
    elif rnk_3 >= 15:
        col_3 = '31'
    str_3 = str(rnk_3).rjust(3)

    rnk_4 = data_dict[teamAway]['Passes']
    col_4 = '30'
    if rnk_4 <= 6:
        col_4 = '32'
    elif rnk_4 >= 15:
        col_4 = '31'
    str_4 = str(rnk_4).rjust(3)

    rnk_5 = data_dict[teamHome]['Shots']
    col_5 = '30'
    if rnk_5 <= 6:
        col_5 = '32'
    elif rnk_5 >= 15:
        col_5 = '31'
    str_5 = str(rnk_5).rjust(3)

    rnk_6 = data_dict[teamAway]['Shots']
    col_6 = '30'
    if rnk_6 <= 6:
        col_6 = '32'
    elif rnk_6 >= 15:
        col_6 = '31'
    str_6 = str(rnk_6).rjust(3)

    statsHome = data_dict[teamHome]['margin stats']
    statsAway = data_dict[teamAway]['margin stats']
 
    spread3 = coeff - data_dict[teamHome]['margin form'] + data_dict[teamAway]['margin form']
    spread4 = coeff + statsHome - statsAway
    
    spread = (spread12 + spread3 + spread4) / 3.
    f.write('{0:4.1f}\n'.format(spread))
    #spread = spread1 

    #print(teamHome.rjust(22) + ' {0:+5.1f} ({1:+5.1f}, {2:+5.1f})   at   '.format(spread, spread1, spread2) + teamAway )
    print(teamHome.rjust(22) + ' {0:+5.1f} ({1:+5.1f}, {2:+5.1f}, {3:+5.1f})    vs.   '.format(spread, spread12, spread3, spread4) + teamAway )
    print()
    #print('penalties:  {0:3d}'.format(data_dict[teamHome]['penalties'][1]).rjust(22))
    #colorpr2('   Corners:     ', str_1, col_1, str_2, col_2)
    colorpr2('   Passes:      ', str_3, col_3, str_4, col_4)
    colorpr2('   Shots:       ', str_5, col_5, str_6, col_6)
    #colorpr2('   BigChances:  ', str_9, col_9, str_10, col_10)
    print()
    
f.close()
# Out:
# coeff =  -0.556666666667
#
#             Birmingham  -0.6 ( -1.2,  -2.6,  +1.8)    vs.   Brentford
#
#    Passes:            24                3
#    Shots:             15                3
#
#                 Bolton  +0.4 ( +0.3,  +0.3,  +0.7)    vs.   Stoke
#
#    Passes:            20                8
#    Shots:             23               18
#
#           Bristol City  -1.4 ( -1.3,  -2.1,  -0.9)    vs.   Rotherham
#
#    Passes:            14               23
#    Shots:             11                7
#
#                  Leeds  -1.8 ( -1.5,  -0.7,  -3.1)    vs.   Hull
#
#    Passes:             4               19
#    Shots:              1               22
#
#          Middlesbrough  -1.7 ( -1.7,  -1.1,  -2.3)    vs.   Ipswich
#
#    Passes:            13               21
#    Shots:              8               24
#
#               Millwall  +0.1 ( +0.2,  -0.1,  +0.0)    vs.   Nottingham Forest
#
#    Passes:            22               10
#    Shots:             13               17
#
#                Norwich  -1.0 ( -0.7,  -1.4,  -0.9)    vs.   Derby
#
#    Passes:             5                7
#    Shots:              2                5
#
#                Preston  +0.4 ( -0.2,  +0.4,  +0.8)    vs.   Aston Villa
#
#    Passes:            15                2
#    Shots:             12                6
#
#    Queens Park Rangers  -1.3 ( -1.0,  -1.9,  -0.9)    vs.   Reading
#
#    Passes:            18               12
#    Shots:             10               21
#
#       Sheffield United  -1.5 ( -1.3,  -1.4,  -1.8)    vs.   Blackburn
#
#    Passes:             9               17
#    Shots:              9               19
#
#                Swansea  -1.3 ( -1.2,  -1.1,  -1.8)    vs.   Wigan
#
#    Passes:             1               16
#    Shots:             14               16
#
#   West Bromwich Albion  -1.9 ( -1.9,  -1.9,  -2.1)    vs.   Sheffield Wednesday
#
#    Passes:             6               11
#    Shots:              4               20
