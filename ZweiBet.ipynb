# %%
import numpy as np
import re

# %%
def redpr(str):
    print('\x1b[31m' + str + '\x1b[0m')
    
def greenpr(str):
    print('\x1b[32m' + str + '\x1b[0m')
    
def colorpr2(str0, str1, col1, str2, col2):
    print(str0 + '\x1b[' + col1 + 'm' + str1.rjust(8) + '\x1b[0m', '\x1b[' + col2 + 'm' + str2.rjust(16) + '\x1b[0m')

# %%
week = 15
lastweek = week - 1
wk = str(week)
lwk = str(lastweek)

with open('Woche' + lwk + '/Spielplan_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Spielplan = list(f)

with open('Woche' + lwk + '/Tabelle_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Tabelle = list(f)
    
with open('Woche' + lwk + '/TabelleHeim_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    TabelleHeim = list(f)
    
with open('Woche' + lwk + '/TabelleAusw_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    TabelleAusw = list(f)
    
with open('Woche' + lwk + '/Torschüsse_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Torschüsse = list(f)
    
with open('Woche' + lwk + '/Passquote_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Passquote = list(f)
    
with open('Woche' + lwk + '/Laufdistanz_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Laufdistanz = list(f)
    
with open('Woche' + lwk + '/Zweikämpfe_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Zweikämpfe = list(f)
    
with open('Woche' + lwk + '/Eckbälle_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Eckbälle = list(f)

# %%
Tabelle
# Out:
# ['1\t1. FC Köln\t1. FC Köln\t14\t8\t3\t3\t35:18\t17\t27\n',
#  '2\tHamburger SV\tHamburger SV\t13\t8\t3\t2\t17:12\t5\t27\n',
#  '3\t1. FC Union Berlin\t1. FC Union Berlin\t13\t5\t8\t0\t19:8\t11\t23\n',
#  '4\tVfL Bochum\tVfL Bochum\t14\t6\t5\t3\t24:16\t8\t23\n',
#  '5\tSpVgg Greuther Fürth\tSpVgg Greuther Fürth\t14\t6\t5\t3\t21:20\t1\t23\n',
#  '6\tFC St. Pauli\tFC St. Pauli\t13\t7\t2\t4\t19:18\t1\t23\n',
#  '7\tHolstein Kiel\tHolstein Kiel\t14\t5\t6\t3\t24:22\t2\t21\n',
#  '8\t1. FC Heidenheim 1846\t1. FC Heidenheim 1846\t13\t5\t5\t3\t20:14\t6\t20\n',
#  '9\tJahn Regensburg\tJahn Regensburg\t13\t5\t5\t3\t24:20\t4\t20\n',
#  '10\tSC Paderborn 07\tSC Paderborn 07\t13\t4\t6\t3\t26:24\t2\t18\n',
#  '11\tDynamo Dresden\tDynamo Dresden\t13\t5\t3\t5\t17:20\t-3\t18\n',
#  '12\tSV Darmstadt 98\tSV Darmstadt 98\t14\t5\t2\t7\t17:21\t-4\t17\n',
#  '13\tErzgebirge Aue\tErzgebirge Aue\t14\t4\t2\t8\t14:20\t-6\t14\n',
#  '14\tArminia Bielefeld\tArminia Bielefeld\t14\t3\t4\t7\t16:22\t-6\t13\n',
#  '15\tMSV Duisburg\tMSV Duisburg\t14\t3\t4\t7\t13:20\t-7\t13\n',
#  '16\tSV Sandhausen\tSV Sandhausen\t14\t2\t4\t8\t14:22\t-8\t10\n',
#  '17\t1. FC Magdeburg\t1. FC Magdeburg\t14\t1\t6\t7\t18:27\t-9\t9\n',
#  '18\tFC Ingolstadt 04\tFC Ingolstadt 04\t13\t1\t5\t7\t13:27\t-14\t8']

# %%
team_list = []
data_dict = {}

for i in range(len(Passquote)):
    
    # Passquote:
    j1 = Passquote[i].index('\t')
    j2 = Passquote[i].index('\t', j1 + 1)
    team = Passquote[i].lstrip().rstrip()[j1 + 1:j2]
    team_list.append(team)
    
    rnk = int(Passquote[i][:j1].rstrip())
    
    data_dict[team] = {}
    data_dict[team]['Passquote'] = rnk
    
team_list = sorted(team_list)

for i in range(len(Passquote)):
    
    # Torschüsse:
    j1 = Torschüsse[i].index('\t')
    j2 = Torschüsse[i].index('\t', j1 + 1)
    team = Torschüsse[i].lstrip().rstrip()[j1 + 1:j2]
    rnk = int(Torschüsse[i][:j1].rstrip())
    data_dict[team]['Torschüsse'] = rnk
    
    # Laufdistanz:
    j1 = Laufdistanz[i].index('\t')
    j2 = Laufdistanz[i].index('\t', j1 + 1)
    team = Laufdistanz[i].lstrip().rstrip()[j1 + 1:j2]
    rnk = int(Laufdistanz[i][:j1].rstrip())
    data_dict[team]['Laufdistanz'] = rnk
    
    # Zweikämpfe:
    j1 = Zweikämpfe[i].index('\t')
    j2 = Zweikämpfe[i].index('\t', j1 + 1)
    team = Zweikämpfe[i].lstrip().rstrip()[j1 + 1:j2]
    rnk = int(Zweikämpfe[i][:j1].rstrip())
    data_dict[team]['Zweikämpfe'] = rnk
    
    # Eckbälle:
    j1 = Eckbälle[i].index('\t')
    j2 = Eckbälle[i].index('\t', j1 + 1)
    team = Eckbälle[i].lstrip().rstrip()[j1 + 1:j2]
    rnk = int(Eckbälle[i][:j1].rstrip())
    data_dict[team]['Eckbälle'] = rnk

# %%
Tabelle
# Out:
# ['1\t1. FC Köln\t1. FC Köln\t14\t8\t3\t3\t35:18\t17\t27\n',
#  '2\tHamburger SV\tHamburger SV\t13\t8\t3\t2\t17:12\t5\t27\n',
#  '3\t1. FC Union Berlin\t1. FC Union Berlin\t13\t5\t8\t0\t19:8\t11\t23\n',
#  '4\tVfL Bochum\tVfL Bochum\t14\t6\t5\t3\t24:16\t8\t23\n',
#  '5\tSpVgg Greuther Fürth\tSpVgg Greuther Fürth\t14\t6\t5\t3\t21:20\t1\t23\n',
#  '6\tFC St. Pauli\tFC St. Pauli\t13\t7\t2\t4\t19:18\t1\t23\n',
#  '7\tHolstein Kiel\tHolstein Kiel\t14\t5\t6\t3\t24:22\t2\t21\n',
#  '8\t1. FC Heidenheim 1846\t1. FC Heidenheim 1846\t13\t5\t5\t3\t20:14\t6\t20\n',
#  '9\tJahn Regensburg\tJahn Regensburg\t13\t5\t5\t3\t24:20\t4\t20\n',
#  '10\tSC Paderborn 07\tSC Paderborn 07\t13\t4\t6\t3\t26:24\t2\t18\n',
#  '11\tDynamo Dresden\tDynamo Dresden\t13\t5\t3\t5\t17:20\t-3\t18\n',
#  '12\tSV Darmstadt 98\tSV Darmstadt 98\t14\t5\t2\t7\t17:21\t-4\t17\n',
#  '13\tErzgebirge Aue\tErzgebirge Aue\t14\t4\t2\t8\t14:20\t-6\t14\n',
#  '14\tArminia Bielefeld\tArminia Bielefeld\t14\t3\t4\t7\t16:22\t-6\t13\n',
#  '15\tMSV Duisburg\tMSV Duisburg\t14\t3\t4\t7\t13:20\t-7\t13\n',
#  '16\tSV Sandhausen\tSV Sandhausen\t14\t2\t4\t8\t14:22\t-8\t10\n',
#  '17\t1. FC Magdeburg\t1. FC Magdeburg\t14\t1\t6\t7\t18:27\t-9\t9\n',
#  '18\tFC Ingolstadt 04\tFC Ingolstadt 04\t13\t1\t5\t7\t13:27\t-14\t8']

# %%
for i in range(len(Passquote)):
    j1 = Tabelle[i].index('\t')
    j2 = Tabelle[i].index('\t', j1 + 1)
    team = Tabelle[i].lstrip().rstrip()[j1 + 1:j2]
    j1 = Tabelle[i].index('\t', j2 + 1)
    j2 = Tabelle[i].index('\t', j1 + 1) 
    games = int(Tabelle[i].lstrip()[j1 + 1:j2].rstrip())
    j1 = Tabelle[i][::-1].index('\t')
    j2 = Tabelle[i][::-1].index('\t', j1 + 1) 
    margin = int(Tabelle[i][::-1][j1 + 1:j2][::-1].rstrip())
    data_dict[team]['margin'] = margin/games
    
    j1 = TabelleHeim[i].index('\t')
    j2 = TabelleHeim[i].index('\t', j1 + 1)
    team = TabelleHeim[i].lstrip().rstrip()[j1 + 1:j2]
    j1 = TabelleHeim[i].index('\t', j2 + 1)
    j2 = TabelleHeim[i].index('\t', j1 + 1) 
    games = int(TabelleHeim[i].lstrip()[j1 + 1:j2].rstrip())
    j1 = TabelleHeim[i][::-1].index('\t')
    j2 = TabelleHeim[i][::-1].index('\t', j1 + 1) 
    margin = int(TabelleHeim[i][::-1][j1 + 1:j2][::-1].rstrip())
    data_dict[team]['marginHeim'] = margin/games
    
    j1 = TabelleAusw[i].index('\t')
    j2 = TabelleAusw[i].index('\t', j1 + 1)
    team = TabelleAusw[i].lstrip().rstrip()[j1 + 1:j2]
    j1 = TabelleAusw[i].index('\t', j2 + 1)
    j2 = TabelleAusw[i].index('\t', j1 + 1) 
    games = int(TabelleAusw[i].lstrip()[j1 + 1:j2].rstrip())
    j1 = TabelleAusw[i][::-1].index('\t')
    j2 = TabelleAusw[i][::-1].index('\t', j1 + 1) 
    margin = int(TabelleAusw[i][::-1][j1 + 1:j2][::-1].rstrip())
    data_dict[team]['marginAusw'] = margin/games
    
data_dict
# Out:
# {'Hamburger SV': {'Passquote': 1,
#   'Torschüsse': 8,
#   'Eckbälle': 8,
#   'Laufdistanz': 11,
#   'Zweikämpfe': 12,
#   'margin': 0.38461538461538464,
#   'marginAusw': 1.3333333333333333,
#   'marginHeim': -0.42857142857142855},
#  '1. FC Köln': {'Passquote': 2,
#   'Eckbälle': 1,
#   'Torschüsse': 2,
#   'Zweikämpfe': 2,
#   'Laufdistanz': 7,
#   'margin': 1.2142857142857142,
#   'marginAusw': 1.4285714285714286,
#   'marginHeim': 1.0},
#  'Holstein Kiel': {'Passquote': 3,
#   'Laufdistanz': 2,
#   'Eckbälle': 3,
#   'Zweikämpfe': 13,
#   'Torschüsse': 17,
#   'margin': 0.14285714285714285,
#   'marginHeim': 0.5714285714285714,
#   'marginAusw': -0.2857142857142857},
#  'VfL Bochum': {'Passquote': 4,
#   'Torschüsse': 9,
#   'Zweikämpfe': 9,
#   'Eckbälle': 11,
#   'Laufdistanz': 13,
#   'margin': 0.5714285714285714,
#   'marginHeim': 0.875,
#   'marginAusw': 0.16666666666666666},
#  'SC Paderborn 07': {'Passquote': 5,
#   'Torschüsse': 1,
#   'Eckbälle': 2,
#   'Zweikämpfe': 4,
#   'Laufdistanz': 15,
#   'margin': 0.15384615384615385,
#   'marginHeim': 0.42857142857142855,
#   'marginAusw': -0.16666666666666666},
#  '1. FC Heidenheim 1846': {'Passquote': 6,
#   'Eckbälle': 4,
#   'Torschüsse': 5,
#   'Laufdistanz': 10,
#   'Zweikämpfe': 10,
#   'margin': 0.46153846153846156,
#   'marginHeim': 1.0,
#   'marginAusw': 0.0},
#  'Erzgebirge Aue': {'Passquote': 7,
#   'Laufdistanz': 5,
#   'Zweikämpfe': 6,
#   'Torschüsse': 14,
#   'Eckbälle': 18,
#   'margin': -0.42857142857142855,
#   'marginHeim': 0.0,
#   'marginAusw': -0.75},
#  'Arminia Bielefeld': {'Passquote': 8,
#   'Laufdistanz': 1,
#   'Torschüsse': 3,
#   'Zweikämpfe': 5,
#   'Eckbälle': 5,
#   'margin': -0.42857142857142855,
#   'marginAusw': -0.5714285714285714,
#   'marginHeim': -0.2857142857142857},
#  'MSV Duisburg': {'Passquote': 9,
#   'Torschüsse': 7,
#   'Laufdistanz': 8,
#   'Zweikämpfe': 8,
#   'Eckbälle': 15,
#   'margin': -0.5,
#   'marginAusw': -0.25,
#   'marginHeim': -0.8333333333333334},
#  'SV Sandhausen': {'Passquote': 10,
#   'Zweikämpfe': 1,
#   'Laufdistanz': 6,
#   'Torschüsse': 11,
#   'Eckbälle': 11,
#   'margin': -0.5714285714285714,
#   'marginAusw': -0.75,
#   'marginHeim': -0.3333333333333333},
#  'Dynamo Dresden': {'Passquote': 11,
#   'Torschüsse': 12,
#   'Zweikämpfe': 14,
#   'Laufdistanz': 16,
#   'Eckbälle': 17,
#   'margin': -0.23076923076923078,
#   'marginAusw': -0.8333333333333334,
#   'marginHeim': 0.2857142857142857},
#  'FC St. Pauli': {'Passquote': 12,
#   'Zweikämpfe': 7,
#   'Eckbälle': 7,
#   'Torschüsse': 10,
#   'Laufdistanz': 17,
#   'margin': 0.07692307692307693,
#   'marginAusw': -0.14285714285714285,
#   'marginHeim': 0.3333333333333333},
#  'FC Ingolstadt 04': {'Passquote': 13,
#   'Eckbälle': 9,
#   'Laufdistanz': 14,
#   'Torschüsse': 16,
#   'Zweikämpfe': 16,
#   'margin': -1.0769230769230769,
#   'marginHeim': -0.2857142857142857,
#   'marginAusw': -2.0},
#  'SpVgg Greuther Fürth': {'Passquote': 14,
#   'Laufdistanz': 4,
#   'Torschüsse': 6,
#   'Zweikämpfe': 15,
#   'Eckbälle': 15,
#   'margin': 0.07142857142857142,
#   'marginHeim': 0.8571428571428571,
#   'marginAusw': -0.7142857142857143},
#  'SV Darmstadt 98': {'Passquote': 15,
#   'Laufdistanz': 9,
#   'Eckbälle': 10,
#   'Zweikämpfe': 11,
#   'Torschüsse': 18,
#   'margin': -0.2857142857142857,
#   'marginHeim': 0.375,
#   'marginAusw': -1.1666666666666667},
#  '1. FC Union Berlin': {'Passquote': 16,
#   'Laufdistanz': 12,
#   'Torschüsse': 13,
#   'Eckbälle': 14,
#   'Zweikämpfe': 17,
#   'margin': 0.8461538461538461,
#   'marginHeim': 1.4285714285714286,
#   'marginAusw': 0.16666666666666666},
#  '1. FC Magdeburg': {'Passquote': 17,
#   'Laufdistanz': 3,
#   'Zweikämpfe': 3,
#   'Eckbälle': 13,
#   'Torschüsse': 15,
#   'margin': -0.6428571428571429,
#   'marginAusw': -0.8571428571428571,
#   'marginHeim': -0.42857142857142855},
#  'Jahn Regensburg': {'Passquote': 18,
#   'Torschüsse': 4,
#   'Eckbälle': 6,
#   'Laufdistanz': 18,
#   'Zweikämpfe': 18,
#   'margin': 0.3076923076923077,
#   'marginAusw': 0.5714285714285714,
#   'marginHeim': 0.0}}

# %%
margin_ar = []
marginHeim_ar = []
marginAusw_ar = []
stats_ar = []
means = np.zeros((18, 2))

i = 0
for team in team_list:
    margin_ar.append([data_dict[team]['margin'], team]) 
    marginHeim_ar.append([data_dict[team]['marginHeim'], team])
    marginAusw_ar.append([data_dict[team]['marginAusw'], team])
    rnk_1 = data_dict[team]['Passquote']
    rnk_2 = data_dict[team]['Torschüsse']
    rnk_3 = data_dict[team]['Zweikämpfe']
    rnk_4 = data_dict[team]['Laufdistanz']
    rnk_5 = data_dict[team]['Eckbälle']
    means[i, 0] = data_dict[team]['marginHeim']
    means[i, 1] = data_dict[team]['marginAusw']
    i +=1
    
    # divided by 3.5 to get the margin:
    stats_val = np.mean([rnk_1, rnk_2, rnk_3, rnk_4, rnk_5])/3.5
    stats_ar.append([stats_val, team, rnk_1, rnk_2, rnk_3, rnk_4, rnk_5])
    data_dict[team]['marginStats'] = stats_val
    
margin_rankings = sorted(margin_ar, reverse=True)
marginHeim_rankings = sorted(marginHeim_ar, reverse=True)
marginAusw_rankings = sorted(marginAusw_ar, reverse=True)
stats_rankings = sorted(stats_ar, reverse=False)

print('meanHeim: ', np.mean(means[:, 0]))
print('meanAusw: ', np.mean(means[:, 1]))
print()

print('margin:')
print()
for i in range(18):
    print('{:2d}'.format(i + 1), margin_rankings[i][1].rjust(30), '{0:+5.1f}'.format(margin_rankings[i][0] ))

print()
print('marginHeim:')
print()
for i in range(18):
    print('{:2d}'.format(i + 1), marginHeim_rankings[i][1].rjust(30), '{0:+5.1f}'.format(marginHeim_rankings[i][0] ))

print()
print('marginAusw:')
print()
for i in range(18):
    print('{:2d}'.format(i + 1), marginAusw_rankings[i][1].rjust(30), '{0:+5.1f}'.format(marginAusw_rankings[i][0] ))

print()
print('marginStats:')
print()
for i in range(18):
    print('{:2d}'.format(i + 1), stats_rankings[i][1].rjust(30), '{0:5.1f}'.format(stats_rankings[i][0]), '  {}'.format(stats_rankings[i][2:] ))
# Out:
# meanHeim:  0.253306878307
# meanAusw:  -0.267857142857
#
# margin:
#
#  1                     1. FC Köln  +1.2
#  2             1. FC Union Berlin  +0.8
#  3                     VfL Bochum  +0.6
#  4          1. FC Heidenheim 1846  +0.5
#  5                   Hamburger SV  +0.4
#  6                Jahn Regensburg  +0.3
#  7                SC Paderborn 07  +0.2
#  8                  Holstein Kiel  +0.1
#  9                   FC St. Pauli  +0.1
# 10           SpVgg Greuther Fürth  +0.1
# 11                 Dynamo Dresden  -0.2
# 12                SV Darmstadt 98  -0.3
# 13                 Erzgebirge Aue  -0.4
# 14              Arminia Bielefeld  -0.4
# 15                   MSV Duisburg  -0.5
# 16                  SV Sandhausen  -0.6
# 17                1. FC Magdeburg  -0.6
# 18               FC Ingolstadt 04  -1.1
#
# marginHeim:
#
#  1             1. FC Union Berlin  +1.4
#  2                     1. FC Köln  +1.0
#  3          1. FC Heidenheim 1846  +1.0
#  4                     VfL Bochum  +0.9
#  5           SpVgg Greuther Fürth  +0.9
#  6                  Holstein Kiel  +0.6
#  7                SC Paderborn 07  +0.4
#  8                SV Darmstadt 98  +0.4
#  9                   FC St. Pauli  +0.3
# 10                 Dynamo Dresden  +0.3
# 11                Jahn Regensburg  +0.0
# 12                 Erzgebirge Aue  +0.0
# 13               FC Ingolstadt 04  -0.3
# 14              Arminia Bielefeld  -0.3
# 15                  SV Sandhausen  -0.3
# 16                   Hamburger SV  -0.4
# 17                1. FC Magdeburg  -0.4
# 18                   MSV Duisburg  -0.8
#
# marginAusw:
#
#  1                     1. FC Köln  +1.4
#  2                   Hamburger SV  +1.3
#  3                Jahn Regensburg  +0.6
#  4                     VfL Bochum  +0.2
#  5             1. FC Union Berlin  +0.2
#  6          1. FC Heidenheim 1846  +0.0
#  7                   FC St. Pauli  -0.1
#  8                SC Paderborn 07  -0.2
#  9                   MSV Duisburg  -0.2
# 10                  Holstein Kiel  -0.3
# 11              Arminia Bielefeld  -0.6
# 12           SpVgg Greuther Fürth  -0.7
# 13                  SV Sandhausen  -0.8
# 14                 Erzgebirge Aue  -0.8
# 15                 Dynamo Dresden  -0.8
# 16                1. FC Magdeburg  -0.9
# 17                SV Darmstadt 98  -1.2
# 18               FC Ingolstadt 04  -2.0
#
# marginStats:
#
#  1                     1. FC Köln   0.8   [2, 2, 2, 7, 1]
#  2              Arminia Bielefeld   1.3   [8, 3, 5, 1, 5]
#  3                SC Paderborn 07   1.5   [5, 1, 4, 15, 2]
#  4          1. FC Heidenheim 1846   2.0   [6, 5, 10, 10, 4]
#  5                  Holstein Kiel   2.2   [3, 17, 13, 2, 3]
#  6                  SV Sandhausen   2.2   [10, 11, 1, 6, 11]
#  7                   Hamburger SV   2.3   [1, 8, 12, 11, 8]
#  8                     VfL Bochum   2.6   [4, 9, 9, 13, 11]
#  9                   MSV Duisburg   2.7   [9, 7, 8, 8, 15]
# 10                 Erzgebirge Aue   2.9   [7, 14, 6, 5, 18]
# 11                1. FC Magdeburg   2.9   [17, 15, 3, 3, 13]
# 12                   FC St. Pauli   3.0   [12, 10, 7, 17, 7]
# 13           SpVgg Greuther Fürth   3.1   [14, 6, 15, 4, 15]
# 14                SV Darmstadt 98   3.6   [15, 18, 11, 9, 10]
# 15                Jahn Regensburg   3.7   [18, 4, 18, 18, 6]
# 16               FC Ingolstadt 04   3.9   [13, 16, 16, 14, 9]
# 17                 Dynamo Dresden   4.0   [11, 12, 14, 16, 17]
# 18             1. FC Union Berlin   4.1   [16, 13, 17, 12, 14]

# %%
Spielplan
# Out:
# ['Erzgebirge Aue\n',
#  'Erzgebirge Aue\n',
#  '-:-\n',
#  'Jahn Regensburg\n',
#  'Jahn Regensburg\n',
#  'Anzeige\n',
#  'SC Paderborn 07\n',
#  'SC Paderborn 07\n',
#  '-:-\n',
#  'Arminia Bielefeld\n',
#  'Arminia Bielefeld\n',
#  'Anzeige\n',
#  '01.12.2018 13:00\n',
#  '1. FC Köln\n',
#  '1. FC Köln\n',
#  '-:-\n',
#  'SpVgg Greuther Fürth\n',
#  'SpVgg Greuther Fürth\n',
#  'Anzeige\n',
#  '1. FC Union Berlin\n',
#  '1. FC Union Berlin\n',
#  '-:-\n',
#  'SV Darmstadt 98\n',
#  'SV Darmstadt 98\n',
#  'Anzeige\n',
#  'FC Ingolstadt 04\n',
#  'FC Ingolstadt 04\n',
#  '-:-\n',
#  'Hamburger SV\n',
#  'Hamburger SV\n',
#  'Anzeige\n',
#  'FC St. Pauli\n',
#  'FC St. Pauli\n',
#  '-:-\n',
#  'Dynamo Dresden\n',
#  'Dynamo Dresden\n',
#  'Anzeige\n',
#  '02.12.2018 13:30\n',
#  'MSV Duisburg\n',
#  'MSV Duisburg\n',
#  '-:-\n',
#  'Holstein Kiel\n',
#  'Holstein Kiel\n',
#  'Anzeige\n',
#  'SV Sandhausen\n',
#  'SV Sandhausen\n',
#  '-:-\n',
#  '1. FC Heidenheim 1846\n',
#  '1. FC Heidenheim 1846\n',
#  'Anzeige\n',
#  '1. FC Magdeburg\n',
#  '1. FC Magdeburg\n',
#  '-:-\n',
#  'VfL Bochum\n',
#  'VfL Bochum']

# %%
for i in range(len(Spielplan)):
    if Spielplan[i] == '-:-\n':
        teamHeim = Spielplan[i - 1].rstrip()
        teamAusw = Spielplan[i + 1].rstrip()
        
        spread1 = - 0.6 - data_dict[teamHeim]['margin'] + data_dict[teamAusw]['margin']
        spread2 = - data_dict[teamHeim]['marginHeim'] + data_dict[teamAusw]['marginAusw']
        
        rnk_1 = data_dict[teamHeim]['Passquote']
        col_1 = '30'
        if rnk_1 <= 5:
            col_1 = '32'
        elif rnk_1 >= 14:
            col_1 = '31'
        str_1 = str(rnk_1).rjust(3)
            
        rnk_2 = data_dict[teamAusw]['Passquote']
        col_2 = '30'
        if rnk_2 <= 5:
            col_2 = '32'
        elif rnk_2 >= 14:
            col_2 = '31'
        str_2 = str(rnk_2).rjust(3)
        
        rnk_3 = data_dict[teamHeim]['Torschüsse']
        col_3 = '30'
        if rnk_3 <= 5:
            col_3 = '32'
        elif rnk_3 >= 14:
            col_3 = '31'
        str_3 = str(rnk_3).rjust(3)
            
        rnk_4 = data_dict[teamAusw]['Torschüsse']
        col_4 = '30'
        if rnk_4 <= 5:
            col_4 = '32'
        elif rnk_4 >= 14:
            col_4 = '31'
        str_4 = str(rnk_4).rjust(3)
        
        rnk_5 = data_dict[teamHeim]['Zweikämpfe']
        col_5 = '30'
        if rnk_5 <= 5:
            col_5 = '32'
        elif rnk_5 >= 14:
            col_5 = '31'
        str_5 = str(rnk_5).rjust(3)
            
        rnk_6 = data_dict[teamAusw]['Zweikämpfe']
        col_6 = '30'
        if rnk_6 <= 5:
            col_6 = '32'
        elif rnk_6 >= 14:
            col_6 = '31'
        str_6 = str(rnk_6).rjust(3)
        
        rnk_9 = data_dict[teamHeim]['Laufdistanz']
        col_9 = '30'
        if rnk_9 <= 5:
            col_9 = '32'
        elif rnk_9 >= 14:
            col_9 = '31'
        str_9 = str(rnk_9).rjust(3)
            
        rnk_10 = data_dict[teamAusw]['Laufdistanz']
        col_10 = '30'
        if rnk_10 <= 5:
            col_10 = '32'
        elif rnk_10 >= 14:
            col_10 = '31'
        str_10 = str(rnk_10).rjust(3)
        
        rnk_11 = data_dict[teamHeim]['Eckbälle']
        col_11 = '30'
        if rnk_11 <= 5:
            col_11 = '32'
        elif rnk_11 >= 14:
            col_11 = '31'
        str_11 = str(rnk_11).rjust(3)
            
        rnk_12 = data_dict[teamAusw]['Eckbälle']
        col_12 = '30'
        if rnk_12 <= 5:
            col_12 = '32'
        elif rnk_12 >= 14:
            col_12 = '31'
        str_12 = str(rnk_12).rjust(3)
        
        statsHeim = data_dict[teamHeim]['marginStats']
        statsAusw = data_dict[teamAusw]['marginStats']
        
        spread3 = - 0.6 + statsHeim - statsAusw 
        
        spread = (spread1 + spread2 + spread3) / 3
        #spread = spread1 
        
        #print(teamHeim.rjust(22) + ' {0:+5.1f} ({1:+5.1f}, {2:+5.1f})   at   '.format(spread, spread1, spread2) + teamAusw )
        print(teamHeim.rjust(22) + ' {0:+5.1f} ({1:+5.1f}, {2:+5.1f}, {3:+5.1f})    vs.   '.format(spread, spread1, spread2, spread3) + teamAusw )
        print()
        #print('penalties:  {0:3d}'.format(data_dict[teamHeim]['penalties'][1]).rjust(22))
        colorpr2('   Passquote:    ', str_1, col_1, str_2, col_2)
        colorpr2('   Torschüsse:   ', str_3, col_3, str_4, col_4)
        colorpr2('   Zweikämpfe:   ', str_5, col_5, str_6, col_6)
        colorpr2('   Laufdistanz:  ', str_9, col_9, str_10, col_10)
        colorpr2('   Eckbälle:     ', str_11, col_11, str_12, col_12)
        print()
# Out:
#         Erzgebirge Aue  -0.2 ( +0.1,  +0.6,  -1.4)    vs.   Jahn Regensburg
#
#    Passquote:           7               18
#    Torschüsse:         14                4
#    Zweikämpfe:          6               18
#    Laufdistanz:         5               18
#    Eckbälle:           18                6
#
#        SC Paderborn 07  -0.8 ( -1.2,  -1.0,  -0.3)    vs.   Arminia Bielefeld
#
#    Passquote:           5                8
#    Torschüsse:          1                3
#    Zweikämpfe:          4                5
#    Laufdistanz:        15                1
#    Eckbälle:            2                5
#
#             1. FC Köln  -2.1 ( -1.7,  -1.7,  -2.9)    vs.   SpVgg Greuther Fürth
#
#    Passquote:           2               14
#    Torschüsse:          2                6
#    Zweikämpfe:          2               15
#    Laufdistanz:         7                4
#    Eckbälle:            1               15
#
#     1. FC Union Berlin  -1.5 ( -1.7,  -2.6,  -0.1)    vs.   SV Darmstadt 98
#
#    Passquote:          16               15
#    Torschüsse:         13               18
#    Zweikämpfe:         17               11
#    Laufdistanz:        12                9
#    Eckbälle:           14               10
#
#       FC Ingolstadt 04  +1.2 ( +0.9,  +1.6,  +1.0)    vs.   Hamburger SV
#
#    Passquote:          13                1
#    Torschüsse:         16                8
#    Zweikämpfe:         16               12
#    Laufdistanz:        14               11
#    Eckbälle:            9                8
#
#           FC St. Pauli  -1.2 ( -0.9,  -1.2,  -1.6)    vs.   Dynamo Dresden
#
#    Passquote:          12               11
#    Torschüsse:         10               12
#    Zweikämpfe:          7               14
#    Laufdistanz:        17               16
#    Eckbälle:            7               17
#
#           MSV Duisburg  +0.2 ( +0.0,  +0.5,  -0.1)    vs.   Holstein Kiel
#
#    Passquote:           9                3
#    Torschüsse:          7               17
#    Zweikämpfe:          8               13
#    Laufdistanz:         8                2
#    Eckbälle:           15                3
#
#          SV Sandhausen  +0.1 ( +0.4,  +0.3,  -0.4)    vs.   1. FC Heidenheim 1846
#
#    Passquote:          10                6
#    Torschüsse:         11                5
#    Zweikämpfe:          1               10
#    Laufdistanz:         6               10
#    Eckbälle:           11                4
#
#        1. FC Magdeburg  +0.3 ( +0.6,  +0.6,  -0.3)    vs.   VfL Bochum
#
#    Passquote:          17                4
#    Torschüsse:         15                9
#    Zweikämpfe:          3                9
#    Laufdistanz:         3               13
#    Eckbälle:           13               11
