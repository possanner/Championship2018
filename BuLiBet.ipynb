# %%
import numpy as np
import re

# %%
def redpr(str):
    print('\x1b[31m' + str + '\x1b[0m')
    
def greenpr(str):
    print('\x1b[32m' + str + '\x1b[0m')
    
def colorpr2(str0, str1, col1, str2, col2):
    print(str0 + '\x1b[' + col1 + 'm' + str1.rjust(8) + '\x1b[0m', '\x1b[' + col2 + 'm' + str2.rjust(16) + '\x1b[0m')

# %%
week = 12
lastweek = week - 1
wk = str(week)
lwk = str(lastweek)

with open('Woche' + lwk + '/Spielplan_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Spielplan = list(f)

with open('Woche' + lwk + '/Tabelle_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Tabelle = list(f)
    
with open('Woche' + lwk + '/TabelleHeim_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    TabelleHeim = list(f)
    
with open('Woche' + lwk + '/TabelleAusw_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    TabelleAusw = list(f)
    
with open('Woche' + lwk + '/TabelleForm_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    TabelleForm = list(f)
    
with open('Woche' + lwk + '/Torschüsse_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Torschüsse = list(f)
    
with open('Woche' + lwk + '/Passquote_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Passquote = list(f)
    
with open('Woche' + lwk + '/Laufdistanz_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Laufdistanz = list(f)
    
with open('Woche' + lwk + '/Zweikämpfe_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Zweikämpfe = list(f)
    
with open('Woche' + lwk + '/IntensivLauf_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    IntensivLauf = list(f)
    
with open('Woche' + lwk + '/Eckbälle_w' + lwk + '.txt') as f:
    #passer = f.readlines()
    Eckbälle = list(f)

# %%
Tab = []
TabHeim = []
TabAusw = []
TabForm = []
for i in range(18):
    Tab.append(re.sub('\t', ' ', Tabelle[i]).rstrip().lstrip())
    TabHeim.append(re.sub('\t', ' ', TabelleHeim[i]).rstrip().lstrip())
    TabAusw.append(re.sub('\t', ' ', TabelleAusw[i]).rstrip().lstrip())
    TabForm.append(re.sub('\t', ' ', TabelleForm[i]).rstrip().lstrip())
    Eckbälle[i] = re.sub('Bayern', 'FC Bayern', Eckbälle[i])
    Eckbälle[i] = re.sub('Bor. M', 'Borussia M', Eckbälle[i])
    Eckbälle[i] = re.sub('1899 Hoffenheim', 'TSG 1899 Hoffenheim', Eckbälle[i])
    Eckbälle[i] = re.sub('Bayer Leverkusen', 'Bayer 04 Leverkusen', Eckbälle[i])
    Eckbälle[i] = re.sub('Werder Bremen', 'SV Werder Bremen', Eckbälle[i])
    Eckbälle[i] = re.sub('sseldorf', 'sseldorf 1895 e.V.', Eckbälle[i])
    Eckbälle[i] = re.sub('SC Freiburg', 'Sport-Club Freiburg', Eckbälle[i])

# %%
team_list = []
data_dict = {}

for i in range(len(Passquote)):
    
    # Passquote:
    team = Passquote[i].lstrip().rstrip()[3:-3]
    team_list.append(team)
    
    rnk = int(Passquote[i][0:2].rstrip())
    
    data_dict[team] = {}
    data_dict[team]['Passquote'] = rnk
    
team_list = sorted(team_list)

for i in range(len(Passquote)):
    
    # Torschüsse:
    end = Torschüsse[i].rstrip()[::-1].index(' ')
    end += 1
    team = Torschüsse[i].lstrip().rstrip()[3:-end]
    rnk = int(Torschüsse[i][0:2].rstrip())
    data_dict[team]['Torschüsse'] = rnk
    
    # Laufdistanz:
    end = Laufdistanz[i].rstrip()[::-1].index(' ')
    end += 1
    team = Laufdistanz[i].lstrip().rstrip()[3:-end]
    rnk = int(Laufdistanz[i][0:2].rstrip())
    data_dict[team]['Laufdistanz'] = rnk
    
    # Zweikämpfe:
    end = Zweikämpfe[i].rstrip()[::-1].index(' ')
    end += 1
    team = Zweikämpfe[i].lstrip().rstrip()[3:-end]
    rnk = int(Zweikämpfe[i][0:2].rstrip())
    data_dict[team]['Zweikämpfe'] = rnk
    
    # IntensivLauf:
    end = IntensivLauf[i].rstrip()[::-1].index(' ')
    end += 1
    team = IntensivLauf[i].lstrip().rstrip()[3:-end]
    rnk = int(IntensivLauf[i][0:2].rstrip())
    data_dict[team]['IntensivLauf'] = rnk
    
    # Eckbälle:
    ind1 = Eckbälle[i].index('\t')
    ind2 = Eckbälle[i].index('\t', ind1 + 1)
    team = Eckbälle[i][ind1 + 1:ind2 ]
    Eckbälle[i] = re.sub('\t', ' ', Eckbälle[i])
    rnk = int(Eckbälle[i][0:2].rstrip())
    data_dict[team]['Eckbälle'] = rnk

# %%
'München'
# Out:
# 'München'

# %%
for i in range(len(Passquote)):
    ind = Tab[i][2:].lstrip().index('  ')
    team = Tab[i][2:].lstrip()[:ind]
    games = int(Tab[i][2:].lstrip()[ind+2:ind+4].rstrip())
    margin = int(Tab[i][-3:])
    data_dict[team]['margin'] = margin/games
    
    ind = TabHeim[i][2:].lstrip().index('  ')
    team = TabHeim[i][2:].lstrip()[:ind]
    games = int(TabHeim[i][2:].lstrip()[ind+2:ind+4].rstrip())
    margin = int(TabHeim[i][-3:])
    data_dict[team]['marginHeim'] = margin/games
    
    ind = TabAusw[i][2:].lstrip().index('  ')
    team = TabAusw[i][2:].lstrip()[:ind]
    games = int(TabAusw[i][2:].lstrip()[ind+2:ind+4].rstrip())
    margin = int(TabAusw[i][-3:])
    data_dict[team]['marginAusw'] = margin/games
    
    ind = TabForm[i][2:].lstrip().index('  ')
    team = TabForm[i][2:].lstrip()[:ind]
    games = int(TabForm[i][2:].lstrip()[ind+2:ind+4].rstrip())
    margin = int(TabForm[i][-3:])
    data_dict[team]['marginForm'] = margin/games
    
data_dict
# Out:
# {'FC Bayern MÃ¼nchen': {'Passquote': 1,
#   'Torschüsse': 1,
#   'Eckbälle': 1,
#   'Laufdistanz': 9,
#   'IntensivLauf': 11,
#   'Zweikämpfe': 15,
#   'marginAusw': 0.8333333333333334,
#   'margin': 0.5454545454545454,
#   'marginForm': -0.2,
#   'marginHeim': 0.2},
#  'Borussia Dortmund': {'Passquote': 2,
#   'Laufdistanz': 2,
#   'IntensivLauf': 3,
#   'Eckbälle': 4,
#   'Torschüsse': 9,
#   'Zweikämpfe': 10,
#   'margin': 1.9090909090909092,
#   'marginHeim': 2.3333333333333335,
#   'marginAusw': 1.4,
#   'marginForm': 1.4},
#  'TSG 1899 Hoffenheim': {'Passquote': 3,
#   'Laufdistanz': 1,
#   'Torschüsse': 2,
#   'Eckbälle': 5,
#   'Zweikämpfe': 8,
#   'IntensivLauf': 10,
#   'marginAusw': 0.8,
#   'marginForm': 1.8,
#   'margin': 0.8181818181818182,
#   'marginHeim': 0.8333333333333334},
#  'SV Werder Bremen': {'Passquote': 3,
#   'Torschüsse': 6,
#   'Laufdistanz': 6,
#   'Zweikämpfe': 6,
#   'IntensivLauf': 8,
#   'Eckbälle': 10,
#   'marginAusw': 0.4,
#   'margin': 0.0,
#   'marginHeim': -0.3333333333333333,
#   'marginForm': -0.6},
#  'Borussia MÃ¶nchengladbach': {'Passquote': 3,
#   'Eckbälle': 2,
#   'Laufdistanz': 3,
#   'Torschüsse': 5,
#   'IntensivLauf': 14,
#   'Zweikämpfe': 18,
#   'margin': 1.1818181818181819,
#   'marginHeim': 2.4,
#   'marginForm': 2.0,
#   'marginAusw': 0.16666666666666666},
#  'Bayer 04 Leverkusen': {'Passquote': 6,
#   'Laufdistanz': 4,
#   'IntensivLauf': 5,
#   'Zweikämpfe': 7,
#   'Torschüsse': 7,
#   'Eckbälle': 8,
#   'marginAusw': -0.3333333333333333,
#   'margin': -0.7272727272727273,
#   'marginForm': -0.4,
#   'marginHeim': -1.2},
#  'Hertha BSC': {'Passquote': 6,
#   'Zweikämpfe': 12,
#   'IntensivLauf': 16,
#   'Eckbälle': 15,
#   'Torschüsse': 17,
#   'Laufdistanz': 18,
#   'marginHeim': 0.4,
#   'margin': -0.09090909090909091,
#   'marginAusw': -0.5,
#   'marginForm': -1.2},
#  '1. FC NÃ¼rnberg': {'Passquote': 8,
#   'Eckbälle': 11,
#   'Laufdistanz': 14,
#   'Zweikämpfe': 16,
#   'IntensivLauf': 17,
#   'Torschüsse': 18,
#   'marginHeim': 0.16666666666666666,
#   'margin': -1.1818181818181819,
#   'marginAusw': -2.8,
#   'marginForm': -2.0},
#  '1. FSV Mainz 05': {'Passquote': 8,
#   'IntensivLauf': 6,
#   'Torschüsse': 10,
#   'Laufdistanz': 11,
#   'Zweikämpfe': 13,
#   'Eckbälle': 15,
#   'marginHeim': 0.3333333333333333,
#   'margin': -0.18181818181818182,
#   'marginForm': -0.4,
#   'marginAusw': -0.8},
#  'VfB Stuttgart': {'Passquote': 10,
#   'Zweikämpfe': 11,
#   'Eckbälle': 12,
#   'Torschüsse': 15,
#   'Laufdistanz': 15,
#   'IntensivLauf': 15,
#   'marginAusw': -1.1666666666666667,
#   'marginForm': -2.2,
#   'margin': -1.4545454545454546,
#   'marginHeim': -1.8},
#  'Hannover 96': {'Passquote': 10,
#   'Zweikämpfe': 3,
#   'IntensivLauf': 4,
#   'Eckbälle': 6,
#   'Laufdistanz': 7,
#   'Torschüsse': 11,
#   'marginForm': 0.0,
#   'marginHeim': 0.0,
#   'margin': -0.7272727272727273,
#   'marginAusw': -1.3333333333333333},
#  'RB Leipzig': {'Passquote': 10,
#   'Zweikämpfe': 1,
#   'Torschüsse': 3,
#   'IntensivLauf': 9,
#   'Eckbälle': 9,
#   'Laufdistanz': 10,
#   'margin': 1.1818181818181819,
#   'marginHeim': 2.0,
#   'marginForm': 2.4,
#   'marginAusw': 0.2},
#  'VfL Wolfsburg': {'Passquote': 10,
#   'IntensivLauf': 2,
#   'Eckbälle': 3,
#   'Zweikämpfe': 4,
#   'Torschüsse': 7,
#   'Laufdistanz': 8,
#   'marginAusw': 0.4,
#   'margin': -0.18181818181818182,
#   'marginForm': -0.6,
#   'marginHeim': -0.6666666666666666},
#  'Fortuna DÃ¼sseldorf 1895 e.V.': {'Passquote': 14,
#   'Torschüsse': 11,
#   'Zweikämpfe': 14,
#   'Laufdistanz': 17,
#   'Eckbälle': 17,
#   'IntensivLauf': 18,
#   'marginHeim': -0.5,
#   'marginForm': -2.2,
#   'margin': -1.3636363636363635,
#   'marginAusw': -2.4},
#  'Sport-Club Freiburg': {'Passquote': 15,
#   'Laufdistanz': 5,
#   'Torschüsse': 13,
#   'IntensivLauf': 13,
#   'Zweikämpfe': 17,
#   'Eckbälle': 18,
#   'marginHeim': -0.16666666666666666,
#   'marginForm': 0.0,
#   'margin': -0.36363636363636365,
#   'marginAusw': -0.6},
#  'FC Schalke 04': {'Passquote': 16,
#   'Zweikämpfe': 9,
#   'IntensivLauf': 12,
#   'Torschüsse': 14,
#   'Eckbälle': 14,
#   'Laufdistanz': 16,
#   'marginForm': -0.2,
#   'margin': -0.6363636363636364,
#   'marginAusw': -0.6666666666666666,
#   'marginHeim': -0.6},
#  'Eintracht Frankfurt': {'Passquote': 17,
#   'IntensivLauf': 1,
#   'Zweikämpfe': 2,
#   'Laufdistanz': 13,
#   'Eckbälle': 13,
#   'Torschüsse': 16,
#   'marginForm': 2.6,
#   'marginAusw': 0.3333333333333333,
#   'margin': 1.1818181818181819,
#   'marginHeim': 2.2},
#  'FC Augsburg': {'Passquote': 18,
#   'Torschüsse': 4,
#   'Zweikämpfe': 5,
#   'IntensivLauf': 7,
#   'Eckbälle': 7,
#   'Laufdistanz': 12,
#   'marginAusw': -0.16666666666666666,
#   'margin': 0.09090909090909091,
#   'marginForm': -0.2,
#   'marginHeim': 0.4}}

# %%
margin_ar = []
marginHeim_ar = []
marginAusw_ar = []
marginForm_ar = []
stats_ar = []
means = np.zeros((18, 2))

i = 0
for team in team_list:
    margin_ar.append([data_dict[team]['margin'], team]) 
    marginHeim_ar.append([data_dict[team]['marginHeim'], team])
    marginAusw_ar.append([data_dict[team]['marginAusw'], team])
    marginForm_ar.append([data_dict[team]['marginForm'], team])
    rnk_1 = data_dict[team]['Passquote']
    rnk_2 = data_dict[team]['Torschüsse']
    rnk_3 = data_dict[team]['Zweikämpfe']
    rnk_4 = data_dict[team]['IntensivLauf']
    rnk_5 = data_dict[team]['Laufdistanz']
    rnk_6 = data_dict[team]['Eckbälle']
    means[i, 0] = data_dict[team]['marginHeim']
    means[i, 1] = data_dict[team]['marginAusw']
    i +=1
    
    # divided by 3.5 to get the margin:
    stats_val = np.mean([rnk_1, rnk_2, rnk_3, rnk_4, rnk_5, rnk_6])/2.5
    stats_ar.append([stats_val, team, rnk_1, rnk_2, rnk_3, rnk_4, rnk_5, rnk_6])
    data_dict[team]['marginStats'] = stats_val
    
margin_rankings = sorted(margin_ar, reverse=True)
marginHeim_rankings = sorted(marginHeim_ar, reverse=True)
marginAusw_rankings = sorted(marginAusw_ar, reverse=True)
marginForm_rankings = sorted(marginForm_ar, reverse=True)
stats_rankings = sorted(stats_ar, reverse=False)

print('meanHeim: ', np.mean(means[:, 0]))
print('meanAusw: ', np.mean(means[:, 1]))
print()

print('margin:')
print()
for i in range(18):
    print('{:2d}'.format(i + 1), margin_rankings[i][1].rjust(30), '{0:+5.1f}'.format(margin_rankings[i][0] ))

print()
print('marginHeim:')
print()
for i in range(18):
    print('{:2d}'.format(i + 1), marginHeim_rankings[i][1].rjust(30), '{0:+5.1f}'.format(marginHeim_rankings[i][0] ))

print()
print('marginAusw:')
print()
for i in range(18):
    print('{:2d}'.format(i + 1), marginAusw_rankings[i][1].rjust(30), '{0:+5.1f}'.format(marginAusw_rankings[i][0] ))

print()
print('marginForm:')
print()
for i in range(18):
    print('{:2d}'.format(i + 1), marginForm_rankings[i][1].rjust(30), '{0:+5.1f}'.format(marginForm_rankings[i][0] ))
     
print()
print('marginStats:')
print()
for i in range(18):
    print('{:2d}'.format(i + 1), stats_rankings[i][1].rjust(30), '{0:5.1f}'.format(stats_rankings[i][0]), '  {}'.format(stats_rankings[i][2:] ))
# Out:
# meanHeim:  0.3333333333333333
# meanAusw:  -0.34629629629629627
#
# margin:
#
#  1              Borussia Dortmund  +1.9
#  2                     RB Leipzig  +1.2
#  3            Eintracht Frankfurt  +1.2
#  4      Borussia MÃ¶nchengladbach  +1.2
#  5            TSG 1899 Hoffenheim  +0.8
#  6             FC Bayern MÃ¼nchen  +0.5
#  7                    FC Augsburg  +0.1
#  8               SV Werder Bremen  +0.0
#  9                     Hertha BSC  -0.1
# 10                  VfL Wolfsburg  -0.2
# 11                1. FSV Mainz 05  -0.2
# 12            Sport-Club Freiburg  -0.4
# 13                  FC Schalke 04  -0.6
# 14                    Hannover 96  -0.7
# 15            Bayer 04 Leverkusen  -0.7
# 16                1. FC NÃ¼rnberg  -1.2
# 17  Fortuna DÃ¼sseldorf 1895 e.V.  -1.4
# 18                  VfB Stuttgart  -1.5
#
# marginHeim:
#
#  1      Borussia MÃ¶nchengladbach  +2.4
#  2              Borussia Dortmund  +2.3
#  3            Eintracht Frankfurt  +2.2
#  4                     RB Leipzig  +2.0
#  5            TSG 1899 Hoffenheim  +0.8
#  6                     Hertha BSC  +0.4
#  7                    FC Augsburg  +0.4
#  8                1. FSV Mainz 05  +0.3
#  9             FC Bayern MÃ¼nchen  +0.2
# 10                1. FC NÃ¼rnberg  +0.2
# 11                    Hannover 96  +0.0
# 12            Sport-Club Freiburg  -0.2
# 13               SV Werder Bremen  -0.3
# 14  Fortuna DÃ¼sseldorf 1895 e.V.  -0.5
# 15                  FC Schalke 04  -0.6
# 16                  VfL Wolfsburg  -0.7
# 17            Bayer 04 Leverkusen  -1.2
# 18                  VfB Stuttgart  -1.8
#
# marginAusw:
#
#  1              Borussia Dortmund  +1.4
#  2             FC Bayern MÃ¼nchen  +0.8
#  3            TSG 1899 Hoffenheim  +0.8
#  4                  VfL Wolfsburg  +0.4
#  5               SV Werder Bremen  +0.4
#  6            Eintracht Frankfurt  +0.3
#  7                     RB Leipzig  +0.2
#  8      Borussia MÃ¶nchengladbach  +0.2
#  9                    FC Augsburg  -0.2
# 10            Bayer 04 Leverkusen  -0.3
# 11                     Hertha BSC  -0.5
# 12            Sport-Club Freiburg  -0.6
# 13                  FC Schalke 04  -0.7
# 14                1. FSV Mainz 05  -0.8
# 15                  VfB Stuttgart  -1.2
# 16                    Hannover 96  -1.3
# 17  Fortuna DÃ¼sseldorf 1895 e.V.  -2.4
# 18                1. FC NÃ¼rnberg  -2.8
#
# marginForm:
#
#  1            Eintracht Frankfurt  +2.6
#  2                     RB Leipzig  +2.4
#  3      Borussia MÃ¶nchengladbach  +2.0
#  4            TSG 1899 Hoffenheim  +1.8
#  5              Borussia Dortmund  +1.4
#  6            Sport-Club Freiburg  +0.0
#  7                    Hannover 96  +0.0
#  8                  FC Schalke 04  -0.2
#  9             FC Bayern MÃ¼nchen  -0.2
# 10                    FC Augsburg  -0.2
# 11            Bayer 04 Leverkusen  -0.4
# 12                1. FSV Mainz 05  -0.4
# 13                  VfL Wolfsburg  -0.6
# 14               SV Werder Bremen  -0.6
# 15                     Hertha BSC  -1.2
# 16                1. FC NÃ¼rnberg  -2.0
# 17                  VfB Stuttgart  -2.2
# 18  Fortuna DÃ¼sseldorf 1895 e.V.  -2.2
#
# marginStats:
#
#  1            TSG 1899 Hoffenheim   1.9   [3, 2, 8, 10, 1, 5]
#  2              Borussia Dortmund   2.0   [2, 9, 10, 3, 2, 4]
#  3                  VfL Wolfsburg   2.3   [10, 7, 4, 2, 8, 3]
#  4            Bayer 04 Leverkusen   2.5   [6, 7, 7, 5, 4, 8]
#  5             FC Bayern MÃ¼nchen   2.5   [1, 1, 15, 11, 9, 1]
#  6               SV Werder Bremen   2.6   [3, 6, 6, 8, 6, 10]
#  7                    Hannover 96   2.7   [10, 11, 3, 4, 7, 6]
#  8                     RB Leipzig   2.8   [10, 3, 1, 9, 10, 9]
#  9      Borussia MÃ¶nchengladbach   3.0   [3, 5, 18, 14, 3, 2]
# 10                    FC Augsburg   3.5   [18, 4, 5, 7, 12, 7]
# 11            Eintracht Frankfurt   4.1   [17, 16, 2, 1, 13, 13]
# 12                1. FSV Mainz 05   4.2   [8, 10, 13, 6, 11, 15]
# 13                  VfB Stuttgart   5.2   [10, 15, 11, 15, 15, 12]
# 14                  FC Schalke 04   5.4   [16, 14, 9, 12, 16, 14]
# 15            Sport-Club Freiburg   5.4   [15, 13, 17, 13, 5, 18]
# 16                1. FC NÃ¼rnberg   5.6   [8, 18, 16, 17, 14, 11]
# 17                     Hertha BSC   5.6   [6, 17, 12, 16, 18, 15]
# 18  Fortuna DÃ¼sseldorf 1895 e.V.   6.1   [14, 11, 14, 18, 17, 17]

# %%
for i in range(len(Spielplan)):
    if Spielplan[i][:5] == '- : -':
        teamHeim = Spielplan[i - 2].rstrip()
        teamAusw = Spielplan[i + 2].rstrip()
        
        spread1 = - 0.7 - data_dict[teamHeim]['margin'] + data_dict[teamAusw]['margin']
        spread2 = - data_dict[teamHeim]['marginHeim'] + data_dict[teamAusw]['marginAusw']
        spread3 = - 0.7 - data_dict[teamHeim]['marginForm'] + data_dict[teamAusw]['marginForm']
        
        rnk_1 = data_dict[teamHeim]['Passquote']
        col_1 = '30'
        if rnk_1 <= 5:
            col_1 = '32'
        elif rnk_1 >= 14:
            col_1 = '31'
        str_1 = str(rnk_1).rjust(3)
            
        rnk_2 = data_dict[teamAusw]['Passquote']
        col_2 = '30'
        if rnk_2 <= 5:
            col_2 = '32'
        elif rnk_2 >= 14:
            col_2 = '31'
        str_2 = str(rnk_2).rjust(3)
        
        rnk_3 = data_dict[teamHeim]['Torschüsse']
        col_3 = '30'
        if rnk_3 <= 5:
            col_3 = '32'
        elif rnk_3 >= 14:
            col_3 = '31'
        str_3 = str(rnk_3).rjust(3)
            
        rnk_4 = data_dict[teamAusw]['Torschüsse']
        col_4 = '30'
        if rnk_4 <= 5:
            col_4 = '32'
        elif rnk_4 >= 14:
            col_4 = '31'
        str_4 = str(rnk_4).rjust(3)
        
        rnk_5 = data_dict[teamHeim]['Zweikämpfe']
        col_5 = '30'
        if rnk_5 <= 5:
            col_5 = '32'
        elif rnk_5 >= 14:
            col_5 = '31'
        str_5 = str(rnk_5).rjust(3)
            
        rnk_6 = data_dict[teamAusw]['Zweikämpfe']
        col_6 = '30'
        if rnk_6 <= 5:
            col_6 = '32'
        elif rnk_6 >= 14:
            col_6 = '31'
        str_6 = str(rnk_6).rjust(3)
        
        rnk_7 = data_dict[teamHeim]['IntensivLauf']
        col_7 = '30'
        if rnk_7 <= 5:
            col_7 = '32'
        elif rnk_7 >= 14:
            col_7 = '31'
        str_7 = str(rnk_7).rjust(3)
            
        rnk_8 = data_dict[teamAusw]['IntensivLauf']
        col_8 = '30'
        if rnk_8 <= 5:
            col_8 = '32'
        elif rnk_8 >= 14:
            col_8 = '31'
        str_8 = str(rnk_8).rjust(3)
        
        rnk_9 = data_dict[teamHeim]['Laufdistanz']
        col_9 = '30'
        if rnk_9 <= 5:
            col_9 = '32'
        elif rnk_9 >= 14:
            col_9 = '31'
        str_9 = str(rnk_9).rjust(3)
            
        rnk_10 = data_dict[teamAusw]['Laufdistanz']
        col_10 = '30'
        if rnk_10 <= 5:
            col_10 = '32'
        elif rnk_10 >= 14:
            col_10 = '31'
        str_10 = str(rnk_10).rjust(3)
        
        rnk_11 = data_dict[teamHeim]['Eckbälle']
        col_11 = '30'
        if rnk_11 <= 5:
            col_11 = '32'
        elif rnk_11 >= 14:
            col_11 = '31'
        str_11 = str(rnk_11).rjust(3)
            
        rnk_12 = data_dict[teamAusw]['Eckbälle']
        col_12 = '30'
        if rnk_12 <= 5:
            col_12 = '32'
        elif rnk_12 >= 14:
            col_12 = '31'
        str_12 = str(rnk_12).rjust(3)
        
        statsHeim = data_dict[teamHeim]['marginStats']
        statsAusw = data_dict[teamAusw]['marginStats']
        
        spread4 = - 0.7 + statsHeim - statsAusw 
        
        spread = (spread1 + spread2 + spread3 + spread4) / 4
        #spread = spread1 
        
        #print(teamHeim.rjust(22) + ' {0:+5.1f} ({1:+5.1f}, {2:+5.1f})   at   '.format(spread, spread1, spread2) + teamAusw )
        print(teamHeim.rjust(22) + ' {0:+5.1f} ({1:+5.1f}, {2:+5.1f}, {3:+5.1f}, {4:+5.1f})    vs.   '.format(spread, spread1, spread2, spread3, spread4) + teamAusw )
        print()
        #print('penalties:  {0:3d}'.format(data_dict[teamHeim]['penalties'][1]).rjust(22))
        colorpr2('   Passquote:    ', str_1, col_1, str_2, col_2)
        colorpr2('   Torschüsse:   ', str_3, col_3, str_4, col_4)
        colorpr2('   Zweikämpfe:   ', str_5, col_5, str_6, col_6)
        colorpr2('   IntensivLauf: ', str_7, col_7, str_8, col_8)
        colorpr2('   Laufdistanz:  ', str_9, col_9, str_10, col_10)
        colorpr2('   Eckbälle:     ', str_11, col_11, str_12, col_12)
        print()
# Out:
#    Bayer 04 Leverkusen  -1.8 ( -1.4,  +0.0,  -2.5,  -3.4)    vs.   VfB Stuttgart
#
#    Passquote:           6               10
#    Torschüsse:          7               15
#    Zweikämpfe:          7               11
#    IntensivLauf:        5               15
#    Laufdistanz:         4               15
#    Eckbälle:            8               12
#
#     FC Bayern MÃ¼nchen  -3.0 ( -2.6,  -2.6,  -2.7,  -4.2)    vs.   Fortuna DÃ¼sseldorf 1895 e.V.
#
#    Passquote:           1               14
#    Torschüsse:          1               11
#    Zweikämpfe:         15               14
#    IntensivLauf:       11               18
#    Laufdistanz:         9               17
#    Eckbälle:            1               17
#
#             Hertha BSC  +1.5 ( +0.2,  +0.4,  +2.3,  +3.0)    vs.   TSG 1899 Hoffenheim
#
#    Passquote:           6                3
#    Torschüsse:         17                2
#    Zweikämpfe:         12                8
#    IntensivLauf:       16               10
#    Laufdistanz:        18                1
#    Eckbälle:           15                5
#
#            FC Augsburg  +0.3 ( +0.4,  -0.1,  +2.1,  -1.3)    vs.   Eintracht Frankfurt
#
#    Passquote:          18               17
#    Torschüsse:          4               16
#    Zweikämpfe:          5                2
#    IntensivLauf:        7                1
#    Laufdistanz:        12               13
#    Eckbälle:            7               13
#
#        1. FSV Mainz 05  +1.3 ( +1.4,  +1.1,  +1.1,  +1.5)    vs.   Borussia Dortmund
#
#    Passquote:           8                2
#    Torschüsse:         10                9
#    Zweikämpfe:         13               10
#    IntensivLauf:        6                3
#    Laufdistanz:        11                2
#    Eckbälle:           15                4
#
#          VfL Wolfsburg  +0.6 ( +0.7,  +0.9,  +2.3,  -1.2)    vs.   RB Leipzig
#
#    Passquote:          10               10
#    Torschüsse:          7                3
#    Zweikämpfe:          4                1
#    IntensivLauf:        2                9
#    Laufdistanz:         8               10
#    Eckbälle:            3                9
#
#          FC Schalke 04  -1.7 ( -1.2,  -2.2,  -2.5,  -0.9)    vs.   1. FC NÃ¼rnberg
#
#    Passquote:          16                8
#    Torschüsse:         14               18
#    Zweikämpfe:          9               16
#    IntensivLauf:       12               17
#    Laufdistanz:        16               14
#    Eckbälle:           14               11
#
#    Sport-Club Freiburg  +0.3 ( -0.3,  +0.6,  -1.3,  +2.1)    vs.   SV Werder Bremen
#
#    Passquote:          15                3
#    Torschüsse:         13                6
#    Zweikämpfe:         17                6
#    IntensivLauf:       13                8
#    Laufdistanz:         5                6
#    Eckbälle:           18               10
#
# Borussia MÃ¶nchengladbach  -2.4 ( -2.6,  -3.7,  -2.7,  -0.4)    vs.   Hannover 96
#
#    Passquote:           3               10
#    Torschüsse:          5               11
#    Zweikämpfe:         18                3
#    IntensivLauf:       14                4
#    Laufdistanz:         3                7
#    Eckbälle:            2                6

# %%
data_dict[teamHeim]['Passquote']
# Out:
# 3

# %%
Spielplan
# Out:
# ['Freitag, 23.11.2018 | 20:30 Uhr\n',
#  'Bayer 04 Leverkusen\n',
#  '\t\n',
#  '- : - (- : -)BayArena\n',
#  '\t\n',
#  'VfB Stuttgart\n',
#  '\t\n',
#  'Samstag, 24.11.2018 | 15:30 Uhr\n',
#  'FC Bayern MÃ¼nchen\n',
#  '\t\n',
#  '- : - (- : -)Allianz Arena\n',
#  '\t\n',
#  'Fortuna DÃ¼sseldorf 1895 e.V.\n',
#  '\t\n',
#  'Hertha BSC\n',
#  '\t\n',
#  '- : - (- : -)Olympiastadion\n',
#  '\t\n',
#  'TSG 1899 Hoffenheim\n',
#  '\t\n',
#  'FC Augsburg\n',
#  '\t\n',
#  '- : - (- : -)WWK ARENA\n',
#  '\t\n',
#  'Eintracht Frankfurt\n',
#  '\t\n',
#  '1. FSV Mainz 05\n',
#  '\t\n',
#  '- : - (- : -)OPEL ARENA\n',
#  '\t\n',
#  'Borussia Dortmund\n',
#  '\t\n',
#  'VfL Wolfsburg\n',
#  '\t\n',
#  '- : - (- : -)Volkswagen Arena\n',
#  '\t\n',
#  'RB Leipzig\n',
#  '\t\n',
#  'Samstag, 24.11.2018 | 18:30 Uhr\n',
#  'FC Schalke 04\n',
#  '\t\n',
#  '- : - (- : -)VELTINS-Arena\n',
#  '\t\n',
#  '1. FC NÃ¼rnberg\n',
#  '\t\n',
#  'Sonntag, 25.11.2018 | 15:30 Uhr\n',
#  'Sport-Club Freiburg\n',
#  '\t\n',
#  '- : - (- : -)Schwarzwald-Stadion\n',
#  '\t\n',
#  'SV Werder Bremen\n',
#  '\t\n',
#  'Sonntag, 25.11.2018 | 18:00 Uhr\n',
#  'Borussia MÃ¶nchengladbach\n',
#  '\t\n',
#  '- : - (- : -)BORUSSIA-PARK\n',
#  '\t\n',
#  'Hannover 96']
